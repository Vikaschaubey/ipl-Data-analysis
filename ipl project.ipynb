# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv("ipl.csv")
ipl
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
ipl.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
ipl.shape
# Out:
# (577, 18)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
ipl['player_of_match'].value_counts()
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
#                   ..
# MN Samuels         1
# S Badrinath        1
# R Bhatia           1
# RE Levi            1
# BCJ Cutting        1
# Name: player_of_match, Length: 187, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# SK Raina          13
# AM Rahane         12
# MEK Hussey        12
# G Gambhir         12
# MS Dhoni          12
# Name: player_of_match, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:5]
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# Name: player_of_match, dtype: int64

# %%
list(ipl['player_of_match'].value_counts()[0:5].keys())
# Out:
# ['CH Gayle', 'YK Pathan', 'AB de Villiers', 'DA Warner', 'RG Sharma']

# %%
plt.figure(figsize=(8,5))
plt.title("Man of the match")
plt.xlabel("NAME OF PLAYER")
plt.ylabel("NO OF MATCH OF THE PLAYER")
plt.bar(list(ipl['player_of_match'].value_counts()[0:5].keys()),list(ipl['player_of_match'].value_counts()[0:5]),color="g")
plt.show()

# %%
ipl['result'].value_counts()
# Out:
# normal       568
# tie            6
# no result      3
# Name: result, dtype: int64

# %%
ipl['toss_decision'].value_counts()
# Out:
# field    315
# bat      262
# Name: toss_decision, dtype: int64

# %%
plt.pie(ipl['toss_decision'].value_counts(),labels=list(ipl['toss_decision'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl['winner'].value_counts()
# Out:
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
plt.pie(ipl['winner'].value_counts(),labels=list(ipl['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl2008=ipl[ipl['season']==2008]
ipl2008.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
ipl2008['winner'].value_counts()
# Out:
# Rajasthan Royals               13
# Kings XI Punjab                10
# Chennai Super Kings             9
# Delhi Daredevils                7
# Mumbai Indians                  7
# Kolkata Knight Riders           6
# Royal Challengers Bangalore     4
# Deccan Chargers                 2
# Name: winner, dtype: int64

# %%
batting_first=ipl[ipl['win_by_runs']!=0]

# %%
batting_first.head()
# Out:
#     id  season        city        date                  team1  \
# 0    1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1    2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 7    8    2008     Chennai  2008-04-23    Chennai Super Kings
# 9   10    2008  Chandigarh  2008-04-25        Kings XI Punjab
# 14  15    2008   Bangalore  2008-04-28    Chennai Super Kings
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1               Kings XI Punjab          Chennai Super Kings           bat
# 7                Mumbai Indians               Mumbai Indians         field
# 9                Mumbai Indians               Mumbai Indians         field
# 14  Royal Challengers Bangalore          Chennai Super Kings           bat
#
#     result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
batting_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               261 non-null    int64
#  1   season           261 non-null    int64
#  2   city             258 non-null    object
#  3   date             261 non-null    object
#  4   team1            261 non-null    object
#  5   team2            261 non-null    object
#  6   toss_winner      261 non-null    object
#  7   toss_decision    261 non-null    object
#  8   result           261 non-null    object
#  9   dl_applied       261 non-null    int64
#  10  winner           261 non-null    object
#  11  win_by_runs      261 non-null    int64
#  12  win_by_wickets   261 non-null    int64
#  13  player_of_match  261 non-null    object
#  14  venue            261 non-null    object
#  15  umpire1          261 non-null    object
#  16  umpire2          261 non-null    object
# ...

# %%
#MAking the histogram
plt.figure(figsize=(7,5))
plt.hist(batting_first['win_by_runs'])
plt.title("Distribution of Runs")
plt.xlabel('Runs')
plt.ylabel('NO of the matches')
plt.show()

# %%
a=batting_first[batting_first['win_by_runs']>120]
a
# Out:
#       id  season       city        date                        team1  \
# 0      1    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 351  352    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
# 497  498    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 560  561    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 351                Pune Warriors                Pune Warriors         field
# 497              Kings XI Punjab              Kings XI Punjab         field
# 560                Gujarat Lions                Gujarat Lions         field
#
#      result  dl_applied                       winner  win_by_runs  \
# 0    normal           0        Kolkata Knight Riders          140
# 351  normal           0  Royal Challengers Bangalore          130
# ...

# %%
batting_first['winner'].value_counts()
# Out:
# Chennai Super Kings            46
# Mumbai Indians                 43
# Kolkata Knight Riders          29
# Kings XI Punjab                28
# Royal Challengers Bangalore    27
# Rajasthan Royals               23
# Delhi Daredevils               18
# Deccan Chargers                18
# Sunrisers Hyderabad            18
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.bar(list(batting_first['winner'].value_counts()[0:3].keys()),list(batting_first['winner'].value_counts()[0:3]),color=["blue","pink","red"])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
batting_second=ipl[ipl['win_by_wickets']!=0]
batting_second.head()
# Out:
#    id  season       city        date             team1  \
# 2   3    2008      Delhi  2008-04-19  Rajasthan Royals
# 3   4    2008     Mumbai  2008-04-20    Mumbai Indians
# 4   5    2008    Kolkata  2008-04-20   Deccan Chargers
# 5   6    2008     Jaipur  2008-04-21   Kings XI Punjab
# 6   7    2008  Hyderabad  2008-04-22   Deccan Chargers
#
#                          team2       toss_winner toss_decision  result  \
# 2             Delhi Daredevils  Rajasthan Royals           bat  normal
# 3  Royal Challengers Bangalore    Mumbai Indians           bat  normal
# 4        Kolkata Knight Riders   Deccan Chargers           bat  normal
# 5             Rajasthan Royals   Kings XI Punjab           bat  normal
# 6             Delhi Daredevils   Deccan Chargers           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 2           0             Delhi Daredevils            0               9
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(batting_second['win_by_wickets'],bins=20)
plt.xlabel("No of wickets")
plt.ylabel("No of matches")
plt.show()

# %%
batting_second['winner'].value_counts()
# Out:
# Royal Challengers Bangalore    42
# Kolkata Knight Riders          39
# Delhi Daredevils               38
# Rajasthan Royals               38
# Mumbai Indians                 37
# Chennai Super Kings            33
# Kings XI Punjab                33
# Sunrisers Hyderabad            15
# Deccan Chargers                11
# Gujarat Lions                   8
# Pune Warriors                   6
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.ylabel("No of matches")
plt.bar(batting_second['winner'].value_counts().keys(),batting_second['winner'].value_counts(),color="r")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(batting_second['winner'].value_counts(),labels=list(batting_second['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(batting_second['winner'].value_counts()[0:3],labels=list(batting_second['winner'].value_counts()[0:3].keys()),autopct='%0.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(batting_second['winner'].value_counts()[0:3].keys(),batting_second['winner'].value_counts()[0:3],color=["red","blue","green"])
plt.show()

# %%
ipl.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
ipl["season"].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: city, dtype: int64

# %%
np.sum(ipl['toss_winner']==ipl['winner'])
# Out:
# 291

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
291/577
# Out:
# 0.5043327556325823

# %%
deliveries=pd.read_csv("IPL_Ball_by_Ball_2008_2022.csv")
deliveries.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
# ...

# %%
deliveries.shape
# Out:
# (225954, 17)

# %%
deliveries['ID'].unique()
# Out:
# array([1312200, 1312199, 1312198, 1312197, 1304116, 1304115, 1304114,
#        1304113, 1304112, 1304111, 1304110, 1304109, 1304108, 1304107,
#        1304106, 1304105, 1304104, 1304103, 1304102, 1304101, 1304100,
#        1304099, 1304098, 1304097, 1304096, 1304095, 1304094, 1304093,
#        1304092, 1304091, 1304090, 1304089, 1304088, 1304087, 1304086,
#        1304085, 1304084, 1304083, 1304082, 1304081, 1304080, 1304079,
#        1304078, 1304077, 1304076, 1304075, 1304074, 1304073, 1304072,
#        1304071, 1304070, 1304069, 1304068, 1304067, 1304066, 1304065,
#        1304064, 1304063, 1304062, 1304061, 1304060, 1304059, 1304058,
#        1304057, 1304056, 1304055, 1304054, 1304053, 1304052, 1304051,
#        1304050, 1304049, 1304048, 1304047, 1254117, 1254116, 1254115,
#        1254114, 1254113, 1254112, 1254111, 1254110, 1254109, 1254108,
#        1254107, 1254106, 1254105, 1254104, 1254103, 1254102, 1254101,
# ...

# %%
match_1=deliveries[deliveries['ID']==1312200]

# %%
match_1.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
match_1.tail()
# Out:
#           ID  innings  overs  ballnumber        batter    bowler  \
# 228  1312200        2     17           3     DA Miller  R Ashwin
# 229  1312200        2     17           4  Shubman Gill  R Ashwin
# 230  1312200        2     17           5  Shubman Gill  R Ashwin
# 231  1312200        2     17           6     DA Miller  R Ashwin
# 232  1312200        2     18           1  Shubman Gill  OC McCoy
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# 228  Shubman Gill        NaN            1           0          1
# 229     DA Miller        NaN            0           0          0
# 230     DA Miller        NaN            1           0          1
# 231  Shubman Gill        NaN            2           0          2
# 232     DA Miller        NaN            6           0          6
#
#      non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 228             0                 0        NaN  NaN               NaN
# ...

# %%
match_1.shape
# Out:
# (233, 17)

# %%
rr=match_1[match_1['innings']==1]

# %%
rr.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
rr['batsman_run'].value_counts()
# Out:
# 0    52
# 1    47
# 4    11
# 2     5
# 6     4
# 3     1
# Name: batsman_run, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.title("Rajasthan Royals Batsman Runs")
plt.xlabel("No of Runs")
plt.ylabel("No of balls")
plt.bar(rr['batsman_run'].value_counts().keys(),rr['batsman_run'].value_counts(),color=['red','blue','green','yellow','brown','orange','violet'])
plt.show()

# %%
rr['kind'].value_counts()
# Out:
# caught               6
# caught and bowled    1
# run out              1
# bowled               1
# Name: kind, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(rr['kind'].value_counts(),labels=list(rr['kind'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
gt=match_1[match_1['innings']==2]
gt.head()
# Out:
#           ID  innings  overs  ballnumber        batter    bowler  \
# 120  1312200        2      0           1       WP Saha  TA Boult
# 121  1312200        2      0           2       WP Saha  TA Boult
# 122  1312200        2      0           3       WP Saha  TA Boult
# 123  1312200        2      0           4  Shubman Gill  TA Boult
# 124  1312200        2      0           5  Shubman Gill  TA Boult
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# 120  Shubman Gill        NaN            0           0          0
# 121  Shubman Gill        NaN            0           0          0
# 122  Shubman Gill        NaN            1           0          1
# 123       WP Saha        NaN            0           0          0
# 124       WP Saha        NaN            0           0          0
#
#      non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 120             0                 0        NaN  NaN               NaN
# ...

# %%
gt['batsman_run'].value_counts()
# Out:
# 0    51
# 1    36
# 2    12
# 4    10
# 6     4
# Name: batsman_run, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.title("Gujarat Titans Batsman Runs")
plt.xlabel("No of Runs")
plt.ylabel("No of balls")
plt.bar(gt['batsman_run'].value_counts().keys(),gt['batsman_run'].value_counts(),color=['red','blue','green','yellow','brown','orange','violet'])
plt.show()

# %%
gt['kind'].value_counts()
# Out:
# caught    2
# bowled    1
# Name: kind, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(gt['kind'].value_counts(),labels=list(gt['kind'].value_counts().keys()),autopct='%0.1f%%')
plt.show()
